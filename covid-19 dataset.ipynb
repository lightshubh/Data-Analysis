# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
data= pd.read_csv(r'C:\Users\light\Downloads\4. covid_19_data.csv')

# %%
df_covid= data.copy()

# %%
df_covid.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702

# %%
df_covid['Date']= pd.to_datetime(df_covid['Date'])

# %%
df_covid.isnull().sum()
# Out:
# Date           0
# State        181
# Region         0
# Confirmed      0
# Deaths         0
# Recovered      0
# dtype: int64

# %%
df_covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455

# %%
# to show null value
sns.heatmap(df_covid.isnull())
plt.show()

# %%
df_covid.head(3)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455
# 2 2020-04-29   NaN      Algeria       3848     444       1702

# %%
df_covid.groupby('Region').sum()
# Out:
#                     Confirmed  Deaths  Recovered
# Region
# Afghanistan              1939      60        252
# Albania                   766      30        455
# Algeria                  3848     444       1702
# Andorra                   743      42        423
# Angola                     27       2          7
# ...                       ...     ...        ...
# West Bank and Gaza        344       2         71
# Western Sahara              6       0          5
# Yemen                       6       0          1
# Zambia                     97       3         54
# Zimbabwe                   32       4          5
#
# [187 rows x 3 columns]

# %%
df_covid.groupby('Region')['Confirmed'].sum().sort_values(ascending= False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
df_covid.groupby('Region')[['Confirmed', 'Recovered']].sum()
# Out:
#                     Confirmed  Recovered
# Region
# Afghanistan              1939        252
# Albania                   766        455
# Algeria                  3848       1702
# Andorra                   743        423
# Angola                     27          7
# ...                       ...        ...
# West Bank and Gaza        344         71
# Western Sahara              6          5
# Yemen                       6          1
# Zambia                     97         54
# Zimbabwe                   32          5
#
# [187 rows x 2 columns]

# %%
df_covid.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455

# %%
df_covid= df_covid[~(df_covid['Confirmed'] < 10)]

# %%
df_covid.head(5)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0 2020-04-29   NaN  Afghanistan       1939      60        252
# 1 2020-04-29   NaN      Albania        766      30        455
# 2 2020-04-29   NaN      Algeria       3848     444       1702
# 3 2020-04-29   NaN      Andorra        743      42        423
# 4 2020-04-29   NaN       Angola         27       2          7

# %%
df_covid.groupby('Region')['Confirmed'].sum().sort_values(ascending= False).head()
# Out:
# Region
# US        1039909
# Spain      236899
# Italy      203591
# France     166536
# UK         166432
# Name: Confirmed, dtype: int64

# %%
df_covid_v1= data.copy()

# %%
df_covid_v1.groupby('Region')['Confirmed'].sum().sort_values(ascending= False).head(10)
# Out:
# Region
# US                1039909
# Spain              236899
# Italy              203591
# France             166543
# UK                 166441
# Germany            161539
# Turkey             117589
# Russia              99399
# Iran                93657
# Mainland China      82862
# Name: Confirmed, dtype: int64

# %%
df_covid_v1.head()
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455
# 2  4/29/2020   NaN      Algeria       3848     444       1702
# 3  4/29/2020   NaN      Andorra        743      42        423
# 4  4/29/2020   NaN       Angola         27       2          7

# %%
df_covid_v1.groupby('Region')['Deaths'].sum().sort_values(ascending= True).head(10)
# Out:
# Region
# Laos                0
# Mongolia            0
# Mozambique          0
# Cambodia            0
# Fiji                0
# Namibia             0
# Nepal               0
# Madagascar          0
# Macau               0
# Papua New Guinea    0
# Name: Deaths, dtype: int64

# %%
df_covid_v1.groupby('Region').get_group('India').iloc[:, [0,2,3,4,5]]
# Out:
#          Date Region  Confirmed  Deaths  Recovered
# 74  4/29/2020  India      33062    1079       8437

# %%
df_covid_v1[df_covid_v1['Region']=='India'].iloc[:, [0,2,3,4,5]]
# Out:
#          Date Region  Confirmed  Deaths  Recovered
# 74  4/29/2020  India      33062    1079       8437

# %%
df_covid_v1.head(2)
# Out:
#         Date State       Region  Confirmed  Deaths  Recovered
# 0  4/29/2020   NaN  Afghanistan       1939      60        252
# 1  4/29/2020   NaN      Albania        766      30        455

# %%
df_covid_v1.sort_values(by= 'Confirmed', ascending= True).head(50)
# Out:
#           Date                             State  \
# 285  4/29/2020                         Recovered
# 284  4/29/2020                         Recovered
# 203  4/29/2020      Diamond Princess cruise ship
# 305  4/29/2020                             Tibet
# 289  4/29/2020         Saint Pierre and Miquelon
# 184  4/29/2020                          Anguilla
# 192  4/29/2020  Bonaire, Sint Eustatius and Saba
# 272  4/29/2020             Northwest Territories
# 288  4/29/2020                  Saint Barthelemy
# 178  4/29/2020                               NaN
# 194  4/29/2020            British Virgin Islands
# 177  4/29/2020                               NaN
# 18   4/29/2020                               NaN
# 126  4/29/2020                               NaN
# 140  4/29/2020                               NaN
# 105  4/29/2020                               NaN
# 98   4/29/2020                               NaN
# 156  4/29/2020                               NaN
# ...

# %%
df_covid_v1.nlargest(n= 50,columns= 'Recovered')
# Out:
#           Date            State                Region  Confirmed  Deaths  \
# 153  4/29/2020              NaN                 Spain     236899   24275
# 285  4/29/2020        Recovered                    US          0       0
# 61   4/29/2020              NaN               Germany     161539    6467
# 76   4/29/2020              NaN                  Iran      93657    5957
# 80   4/29/2020              NaN                 Italy     203591   27682
# 229  4/29/2020            Hubei        Mainland China      68128    4512
# 57   4/29/2020              NaN                France     165093   24087
# 167  4/29/2020              NaN                Turkey     117589    3081
# 22   4/29/2020              NaN                Brazil      79685    5513
# 158  4/29/2020              NaN           Switzerland      29407    1716
# 284  4/29/2020        Recovered                Canada          0       0
# 78   4/29/2020              NaN               Ireland      20253    1190
# ...
